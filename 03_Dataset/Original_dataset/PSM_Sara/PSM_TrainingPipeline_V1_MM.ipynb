# %% [markdown]
# Training Pipeline - YOLOv8 OBB - PSM Project

# %% [markdown]
# #Adicionar uma descrição

# %% [markdown]
# Step 1-Importing the dataset

# %% [markdown]
# Defining Inputs & Parameters

# %% [markdown]
# Training the dataset

# %%
pip install "ultralytics<=8.3.40"
# Out:
# Collecting ultralytics<=8.3.40
#   Downloading ultralytics-8.3.40-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (0.23.0)
# Collecting tqdm>=4.64.0 (from ultralytics<=8.3.40)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (7.1.0)
# Collecting py-cpuinfo (from ultralytics<=8.3.40)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (2.1.1)
# Collecting seaborn>=0.11.0 (from ultralytics<=8.3.40)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\python311\lib\site-packages (from ultralytics<=8.3.40) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas>=1.1.4->ultralytics<=8.3.40) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas>=1.1.4->ultralytics<=8.3.40) (2024.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python311\lib\site-packages (from requests>=2.23.0->ultralytics<=8.3.40) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests>=2.23.0->ultralytics<=8.3.40) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests>=2.23.0->ultralytics<=8.3.40) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests>=2.23.0->ultralytics<=8.3.40) (2025.8.3)
# Requirement already satisfied: filelock in c:\python311\lib\site-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\python311\lib\site-packages (from torch>=1.8.0->ultralytics<=8.3.40) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\python311\lib\site-packages (from torch>=1.8.0->ultralytics<=8.3.40) (1.14.0)
# Requirement already satisfied: networkx in c:\python311\lib\site-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.5)
# Requirement already satisfied: jinja2 in c:\python311\lib\site-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.1.6)
# Requirement already satisfied: fsspec in c:\python311\lib\site-packages (from torch>=1.8.0->ultralytics<=8.3.40) (2025.9.0)
# Requirement already satisfied: colorama in c:\users\mmeni\appdata\roaming\python\python311\site-packages (from tqdm>=4.64.0->ultralytics<=8.3.40) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics<=8.3.40) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics<=8.3.40) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics<=8.3.40) (3.0.2)
# Downloading ultralytics-8.3.40-py3-none-any.whl (898 kB)
#    ---------------------------------------- 0.0/898.5 kB ? eta -:--:--
#    --------------------------------------- 898.5/898.5 kB 20.5 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, tqdm, seaborn, ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.204
#     Uninstalling ultralytics-8.3.204:
#       Successfully uninstalled ultralytics-8.3.204
# Successfully installed py-cpuinfo-9.0.0 seaborn-0.13.2 tqdm-4.67.1 ultralytics-8.3.40
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO(“yolov8n-obb.pt”) # Loads a pre-trained model

results = model.train(data=f”{dataset.location}/yolov8-obb.yaml', epochs=100, imgsz=640)
